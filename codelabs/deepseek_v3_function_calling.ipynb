# %% [markdown]
# <a href="https://colab.research.google.com/github/QwertyJack/colab/blob/main/codelabs/deepseek_v3_function_calling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/google-ai-edge/mediapipe-samples/blob/main/codelabs/litert_inference/gemma3_1b_tflite.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # DeepSeek-V3-0324 Function Calling with vLLM
#
# https://docs.vllm.ai/en/stable/features/tool_calling.html#deepseek-v3-models-deepseek_v3

# %%
# !pip install -U vllm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.2/377.2 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 88.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 93.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 104.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.5/31.5 MB 68.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 113.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 96.2 MB/s eta 0:00:00
# ...

# %%
# !GIT_LFS_SKIP_SMUDGE=1 git clone https://huggingface.co/deepseek-ai/DeepSeek-V3-0324
# Out:
# Cloning into 'DeepSeek-V3-0324'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (199/199), done.
# remote: Compressing objects: 100% (198/198), done.
# remote: Total 203 (delta 13), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (203/203), 2.41 MiB | 2.70 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
from transformers import AutoTokenizer
from vllm.entrypoints.openai.tool_parsers.deepseekv3_tool_parser import DeepSeekV3ToolParser

tokenizer = AutoTokenizer.from_pretrained("DeepSeek-V3-0324")
parser = DeepSeekV3ToolParser(tokenizer)

# %%
parser.extract_tool_calls('<｜tool▁calls▁begin｜><｜tool▁call▁begin｜>function<｜tool▁sep｜>get_current_weather\n```json\n{"location":"Istanbul"}\n```<｜tool▁call▁end｜><｜tool▁calls▁end｜>', None)
# Out:
# ExtractedToolCallInformation(tools_called=True, tool_calls=[ToolCall(id='chatcmpl-tool-d8877e5e3d934afaa2cd3b323c37bff0', type='function', function=FunctionCall(name='get_current_weather', arguments='{"location":"Istanbul"}'))], content=None)

# %%
parser.extract_tool_calls('<｜tool▁calls▁begin｜><｜tool▁call▁begin｜>function<｜tool▁sep｜>tell_joke\n```json\n{"query":"cats"}\n```<｜tool▁call▁end｜><｜tool▁call▁end｜>', None)
# Out:
# ExtractedToolCallInformation(tools_called=True, tool_calls=[ToolCall(id='chatcmpl-tool-de0189700e434b3c9f05f4394977415a', type='function', function=FunctionCall(name='tell_joke', arguments='{"query":"cats"}'))], content=None)
